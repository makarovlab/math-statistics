# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./datasets/House_Rent_Dataset.csv')
df
# Out:
#        Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0     2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1     2022-05-13    2  20000   800       1 out of 3   Super Area
# 2     2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3     2022-07-04    2  10000   800       1 out of 2   Super Area
# 4     2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...          ...  ...    ...   ...              ...          ...
# 4741  2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   object
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Floor              4746 non-null   object
#  5   Area Type          4746 non-null   object
#  6   Area Locality      4746 non-null   object
#  7   City               4746 non-null   object
#  8   Furnishing Status  4746 non-null   object
#  9   Tenant Preferred   4746 non-null   object
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   object
# dtypes: int64(4), object(8)
# memory usage: 445.1+ KB

# %%
df[['Rent', 'Size']].describe()
# Out:
#                Rent         Size
# count  4.746000e+03  4746.000000
# mean   3.499345e+04   967.490729
# std    7.810641e+04   634.202328
# min    1.200000e+03    10.000000
# 25%    1.000000e+04   550.000000
# 50%    1.600000e+04   850.000000
# 75%    3.300000e+04  1200.000000
# max    3.500000e+06  8000.000000

# %%
df[['Rent', 'Size']].corr()
# Out:
#           Rent      Size
# Rent  1.000000  0.413551
# Size  0.413551  1.000000

# %%
plt.figure(figsize=(10, 6))

# %%
fig, axs = plt.subplots(3, 4, figsize=(15, 10))

axs[0][0].hist(df['BHK'])
axs[0][1].hist(df['Area Type'])
axs[0][2].hist(df['City'])
axs[0][3].hist(df['Furnishing Status'])
axs[1][0].hist(df['Tenant Preferred'])
axs[1][1].hist(df['Bathroom'])
axs[1][2].hist(df['Point of Contact'])
axs[2][0].boxplot(df['Rent'])
axs[2][1].hist(df['Rent'])
axs[2][2].boxplot(df['Size'])
axs[2][3].hist(df['Size'])
fig.suptitle('Categorical Plotting')
# Out:
# Text(0.5, 0.98, 'Categorical Plotting')

# %%
plt.hist(df['Area Locality'].value_counts())
# Out:
# (array([2.018e+03, 1.450e+02, 3.200e+01, 2.500e+01, 6.000e+00, 6.000e+00,
#         1.000e+00, 1.000e+00, 0.000e+00, 1.000e+00]),
#  array([ 1. ,  4.6,  8.2, 11.8, 15.4, 19. , 22.6, 26.2, 29.8, 33.4, 37. ]),
#  <BarContainer object of 10 artists>)
